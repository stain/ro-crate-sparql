# %% [markdown]
# # Querying RO-Crate as a knowledge graph
#
# _This tutorial includes content adapted from Paul Houle's [gastrodon example](https://github.com/paulhoule/gastrodon/blob/master/notebooks/local/DBpedia_Schema_Queries.ipynb), see [LICENSE](/edit/LICENSE) for details_

# %% [markdown]
# ## Setup

# %%
import sys
from collections import OrderedDict
from rdflib import Graph,URIRef
from rdflib.parser import URLInputSource
from gastrodon import LocalEndpoint,one,QName
import gzip
import pandas as pd
pd.set_option("display.width",100)
pd.set_option("display.max_colwidth",80)

# %% [markdown]
# ## Loading the graph

# %%
g = Graph()
g.parse("https://w3id.org/ro/doi/10.5281/zenodo.5146227")
g.bind("s","http://schema.org/")

# %% [markdown]
# Because we are in Jupyter Notebook, we'll use [gastrodon](https://github.com/paulhoule/gastrodon) to get a nicer table rendering.

# %%
e = e=LocalEndpoint(g)

# %%
e.select("""
   SELECT ?p (COUNT(*) AS ?cnt) {
      # ?s ?p ?o .
   } GROUP BY ?p ORDER BY DESC(?cnt)
   LIMIT 20
""")
# Out:
#                         cnt
# p
# s:name                  196
# rdf:type                192
# s:author                137
# s:additionalType        115
# s:contributor            61
# s:member                 55
# s:url                    33
# s:description            30
# s:hasPart                25
# s:creativeWorkStatus     24
# s:audience               19
# s:applicationCategory    17
# s:softwareRequirements   17
# s:givenName               9
# s:familyName              9
# s:identifier              7
# s:version                 7
# s:datePublished           6
# s:isBasedOn               5
# s:subjectOf               5

# %%
e.select("""
   SELECT ?type (COUNT(?s) as ?cnt) {
      # ?s a ?type 
   } GROUP BY ?type ORDER BY DESC(?cnt)
""")
# Out:
#                                cnt
# type
# s:Person                        62
# s:DefinedTerm                   34
# s:Role                          30
# s:SoftwareApplication           19
# s:Audience                       9
# s:Dataset                        7
# s:ScholarlyArticle               7
# s:CreativeWork                   6
# s:MediaObject                    3
# s:Organization                   2
# s:WebPage                        2
# s:CreateAction                   2
# s:Periodical                     1
# s:WebSite                        1
# s:Comment                        1
# s:Project                        1
# s:FundingAgency                  1
# s:PresentationDigitalDocument    1
# s:WebPageElement                 1
# s:WebApplication                 1
# s:ReplyAction                    1

# %%
persons = e.select("""
SELECT ?person {
  # ?person a s:Person
}
""")
persons
# Out:
#                                                                              person
# 0                                             https://orcid.org/0000-0001-6022-9825
# 1                                             https://orcid.org/0000-0001-6565-5145
# 2                                             https://orcid.org/0000-0001-6960-357X
# 3                                             https://orcid.org/0000-0001-8131-2150
# 4                                             https://orcid.org/0000-0001-8172-8981
# ..                                                                              ...
# 57  https://www.researchobject.org/2021-packaging-research-artefacts-with-ro-cra...
# 58  https://www.researchobject.org/2021-packaging-research-artefacts-with-ro-cra...
# 59  https://www.researchobject.org/2021-packaging-research-artefacts-with-ro-cra...
# 60  https://www.researchobject.org/2021-packaging-research-artefacts-with-ro-cra...
# 61                                            https://orcid.org/0000-0001-6962-4290
#
# [62 rows x 1 columns]

# %%
orcids = e.select("""
SELECT ?person ?name {
  # ?person a s:Person .
  # ?person s:name ?name .
  FILTER(STRSTARTS(STR(?person), "https://orcid.org/"))
}
LIMIT 5
""")
orcids
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 orcids = e.select("""
#       2 SELECT ?person ?name {
#       3   ?person a s:Person .
#       4   ?person s:name ?name .
#       5   FILTER(STRSTARTS(STR(?person), "https://orcid.org/"))
#       6 }
#       7 LIMIT 5
#       8 """)
#       9 orcids
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/gastrodon/__init__.py:503, in Endpoint.select(self, sparql, **kwargs)
#     487 def select(self,sparql:str,**kwargs) -> pd.DataFrame:
#     488     """
#     489     Perform a SPARQL SELECT query against the endpoint.  To make interactive
#     490     queries easy in the Jupyter environment,  any variable with a name beginning with
#    (...)
#     501     :return: SELECT result as a Pandas DataFrame
#     502     """
# --> 503     result = self.select_raw(sparql,_user_frame=3,**kwargs)
#     504     frame=self._dataframe(result)
#     505     columnNames = {str(x) for x in result.vars}
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/gastrodon/__init__.py:523, in Endpoint.select_raw(self, sparql, _user_frame, **kwargs)
#     513 def select_raw(self,sparql:str,_user_frame=2,**kwargs) -> SPARQLResult:
#     514     """
#     515     Perform a SPARQL SELECT query as would the select method,  but do not
#     516     convert result to a DataFrame,  instead return the original
#    (...)
#     521     :return: result as a SPARQLResult
#     522     """
# --> 523     return self._exec_raw(sparql,self._select,_user_frame,**kwargs)
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/gastrodon/__init__.py:559, in Endpoint._exec_raw(self, sparql, operation, _user_frame, **kwargs)
#     557     if "_inject_post_substitute_fault" in kwargs:
#     558         sparql=kwargs["_inject_post_substitute_fault"]
# --> 559     result = operation(sparql, **kwargs)
#     560 except ParseException as x:
#     561     lines= self._error_header()
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/gastrodon/__init__.py:798, in LocalEndpoint._select(self, sparql, **kwargs)
#     797 def _select(self, sparql:str,**kwargs) -> SPARQLResult:
# --> 798     return self.graph.query(sparql)
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/graph.py:1567, in Graph.query(self, query_object, processor, result, initNs, initBindings, use_store_provided, **kwargs)
#    1564     processor = plugin.get(processor, query.Processor)(self)
#    1566 # type error: Argument 1 to "Result" has incompatible type "Mapping[str, Any]"; expected "str"
# -> 1567 return result(processor.query(query_object, initBindings, initNs, **kwargs))
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/processor.py:137, in SPARQLProcessor.query(self, strOrQuery, initBindings, initNs, base, DEBUG)
#     135 if not isinstance(strOrQuery, Query):
#     136     parsetree = parseQuery(strOrQuery)
# --> 137     query = translateQuery(parsetree, base, initNs)
#     138 else:
#     139     query = strOrQuery
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:934, in translateQuery(q, base, initNs)
#     931 prologue = translatePrologue(q[0], base, initNs)
#     933 # absolutize/resolve prefixes
# --> 934 q[1] = traverse(
#     935     q[1], visitPost=functools.partial(translatePName, prologue=prologue)
#     936 )
#     938 P, PV = translate(q[1])
#     939 datasetClause = q[1].datasetClause
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:469, in traverse(tree, visitPre, visitPost, complete)
#     462 """
#     463 Traverse tree, visit each node with visit function
#     464 visit function may raise StopTraversal to stop traversal
#     465 if complete!=None, it is returned on complete traversal,
#     466 otherwise the transformed tree is returned
#     467 """
#     468 try:
# --> 469     r = _traverse(tree, visitPre, visitPost)
#     470     if complete is not None:
#     471         return complete
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:426, in _traverse(e, visitPre, visitPost)
#     424 elif isinstance(e, CompValue):
#     425     for k, val in e.items():
# --> 426         e[k] = _traverse(val, visitPre, visitPost)
#     428 # type error: Statement is unreachable
#     429 _e = visitPost(e)  # type: ignore[unreachable]
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:426, in _traverse(e, visitPre, visitPost)
#     424 elif isinstance(e, CompValue):
#     425     for k, val in e.items():
# --> 426         e[k] = _traverse(val, visitPre, visitPost)
#     428 # type error: Statement is unreachable
#     429 _e = visitPost(e)  # type: ignore[unreachable]
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:419, in _traverse(e, visitPre, visitPost)
#     416     return None
#     418 if isinstance(e, (list, ParseResults)):
# --> 419     return [_traverse(x, visitPre, visitPost) for x in e]
#     420 # type error: Statement is unreachable
#     421 elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:419, in <listcomp>(.0)
#     416     return None
#     418 if isinstance(e, (list, ParseResults)):
# --> 419     return [_traverse(x, visitPre, visitPost) for x in e]
#     420 # type error: Statement is unreachable
#     421 elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:426, in _traverse(e, visitPre, visitPost)
#     424 elif isinstance(e, CompValue):
#     425     for k, val in e.items():
# --> 426         e[k] = _traverse(val, visitPre, visitPost)
#     428 # type error: Statement is unreachable
#     429 _e = visitPost(e)  # type: ignore[unreachable]
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:419, in _traverse(e, visitPre, visitPost)
#     416     return None
#     418 if isinstance(e, (list, ParseResults)):
# --> 419     return [_traverse(x, visitPre, visitPost) for x in e]
#     420 # type error: Statement is unreachable
#     421 elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:419, in <listcomp>(.0)
#     416     return None
#     418 if isinstance(e, (list, ParseResults)):
# --> 419     return [_traverse(x, visitPre, visitPost) for x in e]
#     420 # type error: Statement is unreachable
#     421 elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:419, in _traverse(e, visitPre, visitPost)
#     416     return None
#     418 if isinstance(e, (list, ParseResults)):
# --> 419     return [_traverse(x, visitPre, visitPost) for x in e]
#     420 # type error: Statement is unreachable
#     421 elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:419, in <listcomp>(.0)
#     416     return None
#     418 if isinstance(e, (list, ParseResults)):
# --> 419     return [_traverse(x, visitPre, visitPost) for x in e]
#     420 # type error: Statement is unreachable
#     421 elif isinstance(e, tuple):  # type: ignore[unreachable]
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:429, in _traverse(e, visitPre, visitPost)
#     426         e[k] = _traverse(val, visitPre, visitPost)
#     428 # type error: Statement is unreachable
# --> 429 _e = visitPost(e)  # type: ignore[unreachable]
#     430 if _e is not None:
#     431     return _e
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/algebra.py:197, in translatePName(p, prologue)
#     194 if isinstance(p, CompValue):
#     195     if p.name == "pname":
#     196         # type error: Incompatible return value type (got "Union[CompValue, str, None]", expected "Optional[Identifier]")
# --> 197         return prologue.absolutize(p)  # type: ignore[return-value]
#     198     if p.name == "literal":
#     199         # type error: Argument "datatype" to "Literal" has incompatible type "Union[CompValue, str, None]"; expected "Optional[str]"
#     200         return Literal(
#     201             p.string, lang=p.lang, datatype=prologue.absolutize(p.datatype)  # type: ignore[arg-type]
#     202         )
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/sparql.py:430, in Prologue.absolutize(self, iri)
#     428 if isinstance(iri, CompValue):
#     429     if iri.name == "pname":
# --> 430         return self.resolvePName(iri.prefix, iri.localname)
#     431     if iri.name == "literal":
#     432         # type error: Argument "datatype" to "Literal" has incompatible type "Union[CompValue, Identifier, None]"; expected "Optional[str]"
#     433         return Literal(
#     434             iri.string, lang=iri.lang, datatype=self.absolutize(iri.datatype)  # type: ignore[arg-type]
#     435         )
#
# File ~/miniconda3/envs/ro-crate-sparql/lib/python3.11/site-packages/rdflib/plugins/sparql/sparql.py:412, in Prologue.resolvePName(self, prefix, localname)
#     410 ns = self.namespace_manager.store.namespace(prefix or "")
#     411 if ns is None:
# --> 412     raise Exception("Unknown namespace prefix : %s" % prefix)
#     413 return URIRef(ns + (localname or ""))
#
# Exception: Unknown namespace prefix : s

# %%
for orcid in orcids.person:
    print("Parsing", orcid)
    g.parse(str(orcid), format="json-ld")
# Out:
# Parsing https://orcid.org/0000-0001-6022-9825
# Parsing https://orcid.org/0000-0001-6565-5145
# Parsing https://orcid.org/0000-0001-6960-357X
# https://doi.org/10.1007/978-3-642-16558-0\_22 does not look like a valid URI, trying to serialize this will break.
# Parsing https://orcid.org/0000-0001-8131-2150
# Parsing https://orcid.org/0000-0001-8172-8981
# Parsing https://orcid.org/0000-0001-8420-5254
# Parsing https://orcid.org/0000-0001-9842-9718
# Parsing https://orcid.org/0000-0002-0048-3300
# Parsing https://orcid.org/0000-0002-0309-604X
# Parsing https://orcid.org/0000-0002-0337-8610

# %%
g.bind("s","http://schema.org/") ## latest g.parse might have changes prefixes
e.select("""
   SELECT ?work ?title {
      # ?work s:creator ?person .
      # ?work s:name ?title
   } 
""")
# Out:
#                                                 work  \
# 0                    https://doi.org/10.1145/3486897
# 1       https://doi.org/10.1371/journal.pcbi.1009823
# 2     https://doi.org/10.12688/f1000research.54159.1
# 3             https://doi.org/10.5281/zenodo.5093125
# 4               https://doi.org/10.7717/peerj-cs.387
# ...                                              ...
# 1309               Ndc6aba2a27ae464bbe736805430e9c8d
# 1310               Nfbdee1f111b5432eb04519475e594370
# 1311               N0e988b178f76476cac94601db04e6ad4
# 1312               Ndd74667de24b46619211d33d41d4d641
# 1313               Ne70e8b6b88b44129b7b2adcdf72eeebe
#
#                                                                                 title
# 0                                                                    Methods Included
# 1                          Ten simple rules for making a software tool workflow-ready
# 2     Perspectives on automated composition of workflows in the life sciences [ver...
# 3         Towards a Common Standard for Data and Specimen Provenance in Life Sciences
# 4            Semantic micro-contributions with decentralized nanopublication services
# ...                                                                               ...
# 1309  Quantifying Groundwater Fluctuations in the Southern High Plains with GIS an...
# 1310           Investigating Depletion of the Southern High Plains (Ogallala) Aquifer
# 1311   Integrating GPS and GIS Techniques in Training GIS Professionals: A Case Study
# 1312      Victory Drive Tree Inventory Data Creation and Assessment & ESRI Internship
# 1313  Deep Semantics in the Geosciences: semantic building blocks for a complete g...
#
# [1314 rows x 2 columns]

# %%
dois = e.select("""
   SELECT ?work {
      # ?work s:creator ?person .
      FILTER(STRSTARTS(STR(?work), "https://doi.org/"))
   } 
   LIMIT 5
""")
dois
# Out:
#                                               work
# 0                  https://doi.org/10.1145/3486897
# 1     https://doi.org/10.1371/journal.pcbi.1009823
# 2   https://doi.org/10.12688/f1000research.54159.1
# 3           https://doi.org/10.5281/zenodo.5093125
# 4             https://doi.org/10.7717/peerj-cs.387
# 5           https://doi.org/10.5281/zenodo.4541002
# 6     https://doi.org/10.6084/m9.figshare.14453031
# 7  https://doi.org/10.6084/m9.figshare.14453031.v1
# 8     https://doi.org/10.1007/978-3-030-80960-7_16
# 9           https://doi.org/10.5281/zenodo.3541888

# %%
for doi in dois.work:
    print("Parsing", doi)
    try:
        g.parse(str(doi))
    except Exception as ex:
        print("  Failed", repr(ex))
# Out:
# Parsing https://doi.org/10.1145/3486897
# Parsing https://doi.org/10.1371/journal.pcbi.1009823
# Parsing https://doi.org/10.12688/f1000research.54159.1
# Parsing https://doi.org/10.5281/zenodo.5093125
#   Failed <HTTPError 422: 'Unprocessable Entity'>
# Parsing https://doi.org/10.7717/peerj-cs.387
# Parsing https://doi.org/10.5281/zenodo.4541002
#   Failed <HTTPError 422: 'Unprocessable Entity'>
# Parsing https://doi.org/10.6084/m9.figshare.14453031
#   Failed <HTTPError 422: 'Unprocessable Entity'>
# Parsing https://doi.org/10.6084/m9.figshare.14453031.v1
#   Failed <HTTPError 422: 'Unprocessable Entity'>
# Parsing https://doi.org/10.1007/978-3-030-80960-7_16
# Parsing https://doi.org/10.5281/zenodo.3541888
#   Failed <HTTPError 422: 'Unprocessable Entity'>

# %%
g4 = Graph()
g4.parse("https://doi.org/10.1145/3486897")
e4 = LocalEndpoint(g4)
e4.select("""
SELECT ?s ?p ?o WHERE {
  # ?s ?p ?o
}
""")
# Out:
#                                                                     s                p  \
# 0                                   http://dx.doi.org/10.1145/3486897          j.2:doi
# 1   http://id.crossref.org/contributor/the-cwl-community-vltbu40m1soi  foaf:familyName
# 2                               http://id.crossref.org/issn/0001-0782         j.2:issn
# 3                                   http://dx.doi.org/10.1145/3486897       j.2:volume
# 4       http://id.crossref.org/contributor/peter-amstutz-vltbu40m1soi   foaf:givenName
# ..                                                                ...              ...
# 73                                  http://dx.doi.org/10.1145/3486897  dcterms:creator
# 74                                  http://dx.doi.org/10.1145/3486897  dcterms:creator
# 75      http://id.crossref.org/contributor/herve-menager-vltbu40m1soi        foaf:name
# 76    http://id.crossref.org/contributor/alexandru-iosup-vltbu40m1soi        foaf:name
# 77    http://id.crossref.org/contributor/nebojsa-tijanic-vltbu40m1soi   foaf:givenName
#
#                                                                   o
# 0                                                   10.1145/3486897
# 1                                                         Community
# 2                                                         0001-0782
# 3                                                                65
# 4                                                             Peter
# ..                                                              ...
# 73    http://id.crossref.org/contributor/peter-amstutz-vltbu40m1soi
# 74  http://id.crossref.org/contributor/nebojsa-tijanic-vltbu40m1soi
# 75                                                    Hervé Ménager
# 76                                                  Alexandru Iosup
# 77                                                          Nebojša
#
# [78 rows x 3 columns]

# %% [markdown]
# We see that the DOI metadata follow a different metadata standard, the "classic" FOAF and DC Terms. In addition the URLs for each work now begins with `http://dx.doi.org/` instead of `https://doi.org/` as in the ORCID and RO-Crate.
#
# In addition we see that authors (aka `dcterms:creator` here are not identified by ORCID but by `http://id.crossref.org` internal identifier -- again this is similar as we saw before, not every author will have an ORCID.
#
# This means we have to do a bit more work to combine these data sources in a single knowledge graph.
